# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/mnt/d/piicture/pexels-fox-1172675.jpg")

# %%
cv2.imshow("This is a flower!", img)

cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# QObject::moveToThread: Current thread (0x25d4d170) is not the object's thread (0x26810480).
# Cannot move to target thread (0x25d4d170)
#
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (4000, 6000, 3)

# %%
cv2.imwrite("/mnt/d/piicture/output.jpeg", img)
cv2.imwrite("/mnt/d/piicture/output.png", img)
# Out:
# True

# %%
plt.imshow(img)

# %%
img_RGB1 = img[:, :, ::-1]

# %%
plt.imshow(img_RGB1)

# %%
img_RGB2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_RGB2)

# %%
img_RGB1[1500:2500, 2000:4000, :] = 255
plt.imshow(img_RGB1)

# %%
img_RGB1[1500:2500, 2000:4000, :] = 0
plt.imshow(img_RGB1)

# %%
img_RGB1[1500:2500, 2000:4000, :] = (255, 0, 0)
plt.imshow(img_RGB1)
