# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/mnt/d/piicture/pexels-fox-1172675.jpg")

cv2.imshow("Original Image", img)
cv2.waitKey()

gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Image", gray_img)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# ...

# %%
img = cv2.imread("/mnt/d/piicture/pexels-fox-1172675.jpg", 0)

cv2.imshow("Original Image", img)
cv2.waitKey()
cv2.destroyAllWindows()

print(img.shape)
# Out:
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# QObject::moveToThread: Current thread (0xe2c3860) is not the object's thread (0xdc574e0).
# Cannot move to target thread (0xe2c3860)
#
# ...

# %%
plt.imshow(img, cmap="gray")

# %%
img_orig = cv2.imread("/mnt/d/piicture/pexels-fox-1172675.jpg")
img_gray = cv2.cvtColor(img_orig, cv2.COLOR_BGR2GRAY)

B, G, R = img_orig[2000, 3000]
print(f"B:{B} G:{G} R:{R}")
print(img_gray[2000, 3000])
# Out:
# B:92 G:157 R:41
# 115

# %%
round(0.2989 * R + 0.5870 * G + 0.1140 * B)
# Out:
# 115

# %%
img_new = img_orig[..., 0] // 3 + img_orig[..., 1] // 3 + img_orig[..., 2] // 3

plt.imshow(img_new, cmap="gray")
