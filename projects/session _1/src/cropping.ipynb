# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/mnt/d/piicture/pexels-fox-1172675.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
height, width, channel = img.shape

cropped = img[1500:2500, 2500:3600]
plt.imshow(cropped)

# %%
cropped_2 = img[height//2:3*height//4, width//2:3*width//4]

plt.imshow(cropped_2)
