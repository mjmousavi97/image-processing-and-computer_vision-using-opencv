# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/mnt/f/ds004856-download/dlbs_templates/DLBS268_atlas.png", cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (740, 690, 4)

# %%
bgr_img = img[..., 0:3]
alpha_img = img[..., -1]

rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img); plt.title("RGB Image")
# Out:
# Text(0.5, 1.0, 'RGB Image')

# %%
plt.imshow(alpha_img, cmap="gray")
